# %% [markdown]
# <a href="https://colab.research.google.com/github/jerielizabeth/Workshops-DataVisualization/blob/main/REL503_Pandas_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/melaniewalsh/Intro-Cultural-Analytics/master/book/data/Trans-Atlantic-Slave-Trade_Americas.csv', delimiter=",")

# %%
df
# Out:
#        year_of_arrival               flag          place_of_purchase  \
# 0                 1520                NaN          Portuguese Guinea
# 1                 1525  Portugal / Brazil                   Sao Tome
# 2                 1526    Spain / Uruguay         Cape Verde Islands
# 3                 1526    Spain / Uruguay         Cape Verde Islands
# 4                 1526                NaN         Cape Verde Islands
# ...                ...                ...                        ...
# 20736             1864    Spain / Uruguay  Africa., port unspecified
# 20737             1865    Spain / Uruguay  Africa., port unspecified
# 20738             1865                NaN  Africa., port unspecified
# 20739             1865                NaN                Congo River
# 20740             1866                NaN  Africa., port unspecified
#
#                      place_of_landing  percent_women  percent_children  \
# ...

# %% [markdown]
# Using the following commands, get a sense of the values in the data
#
# * `df.sample()`
# * `df.info()`
# * `df.describe()`
# * `df.describe(include='all')`

# %%
 # enter your code here

# %% [markdown]
# Use the following commands to aggregate the data
#
# * `df['column_name'].sum()`
# * `df['column_name'].count()`
# * `df['column_name'].value_counts()`

# %%
# enter your code here

# %% [markdown]
# What other sorts of operations might you want to do to modify this data for visualizing?
